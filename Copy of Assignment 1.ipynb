# %%
a=input("Enter a String")
# Out:
# Enter a StringShravani

# %%
("Length of input String is:",len(a))
# Out:
# ('Length of input String is:', 8)

# %%
b=float(input("Enter any number"))
# Out:
# Enter any number10

# %%
print("The square root of the number is:",b*b)
# Out:
# The square root of the number is: 100.0

# %%
c=float(input("Enter the temp in celcius"))
# Out:
# Enter the temp in celcius10

# %%
f=(c*9/5)+32
print("The coversion from celcius to fahrenheit is",f)
# Out:
# The coversion from celcius to fahrenheit is 50.0

# %%
n1=10
print(type(n1))
# Out:
# <class 'int'>

# %%
n2=4.5
print(type(n2))
# Out:
# <class 'float'>

# %%
n3=2+6j
print(type(n3))
# Out:
# <class 'complex'>
